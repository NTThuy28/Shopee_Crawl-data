# %%
import pandas as pd
import io
import matplotlib.pyplot as plt

# %%
df_group_follower = pd.read_csv('D:\Final project program\Data\shop_details.csv')

# %%
df_group_follower
# Out:
#         shopid     userid                        name  follower_count  \
# 0    996413308  996580275                  picetechhn            1715
# 1    928141444  928227561       EARFUN OFFICIAL STORE            5104
# 2    928285061  928371313            BASE|US VIET NAM            4309
# 3    391822974  391842551  Chợ Kim Biên Giá Tốt Sỉ Lẻ            8380
# 4    795419791  795403544     JA.Audio Official Store              49
# ..         ...        ...                         ...             ...
# 517  746598167  746617752            Misslife_offcial             953
# 518  749533597  749553182                Padabanic777           16960
# 519  728075325  728094910         Biyi Official Store             447
# 520  799040168  799023921         Eufy Official Store           53175
# 521  595325295  595344880                     SUNDYVN            4220
#
#      show_official_shop_label  is_shopee_verified  rating_star  item_count  \
# ...

# %%
plt.hist(df_group_follower['follower_count'], bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_follower = df_group_follower['follower_count']

# %%
plt.hist(data_follower[data_follower <=600000])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
